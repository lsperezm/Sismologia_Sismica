# %% [markdown]
# # Actividad 2 Sismo Kamchatka, Rusia M8.8
# Laura Sofia Pérez
#
# ## Parte 1: Usando 3 estaciones a 10$^\circ$ del epicentro

# %%
from obspy import read

# %%
file = read('2025-07-29-mww88-off-east-coast-of-kamchatka.miniseed')
#print(st)
st_PET=file[:6]
st_MA2=file[6:12]
st_YSS=file[12:]
print(st_YSS[0].stats, len(st_PET), len(st_MA2), len(st_YSS))
# Out:
#          network: IU
#          station: YSS
#         location: 00
#          channel: BH1
#        starttime: 2025-07-29T23:26:48.000000Z
#          endtime: 2025-07-29T23:37:48.000000Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 13201
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'M', 'number_of_records': 112, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 512, 'filesize': 1771008}) 6 6 6

# %% [markdown]
# ### Estación 1: PET
# Ubicación: 1.11$^\circ$ \
# Azimuth: -61.08$^\circ$\
# Elevación: 110m

# %%
#Canal 1
st_PET[0].plot()

# %%
# Canal 2
st_PET[1].plot()

# %%
#Canal 3
st_PET[2].plot()

# %%
#Canal 4
st_PET[3].plot()

# %%
#Canal 5
st_PET[4].plot()

# %%
#Canal 6
st_PET[5].plot()

# %% [markdown]
# ### Estación 2: MA2
#
# Distancia: 8.83$^\circ$ \
# Azimuth: -32.98$^\circ$ \
# Elevación: 337m

# %%
# Canal 1
st_MA2[0].plot()

# %%
# Canal 2
st_MA2[1].plot()

# %%
# Canal 3
st_MA2[2].plot()

# %%
# Canal 4
st_MA2[3].plot()

# %%
# Canal 5
st_MA2[4].plot()

# %%
# Canal 6
st_MA2[5].plot()

# %% [markdown]
# ### Estación 3: YSS
#
# Distancia: 12.55$^\circ$\
# Azimuth: -109.19$^\circ$\
# Elevación: 150m

# %%
# Canal 1
st_YSS[0].plot()

# %%
# Canal 2
st_YSS[1].plot()

# %%
# Canal 3
st_YSS[2].plot()

# %%
# Canal 4
st_YSS[3].plot()

# %%
# Canal 5
st_YSS[4].plot()

# %%
# Canal 6
st_YSS[5].plot()

# %% [markdown]
# ## Parte 2: Usando 2 estaciones en la zona de sombra

# %%
file = read('2025-07-29-mww88-off-east-coast-of-kamchatka-2.miniseed')
#print(st)
st_NNA=file[:6]
st_RPN=file[6:]
print(st_NNA[5].stats, len(st_NNA), len(st_RPN))
# Out:
#          network: II
#          station: NNA
#         location: 10
#          channel: BHZ
#        starttime: 2025-07-29T23:38:58.019538Z
#          endtime: 2025-07-29T23:49:57.994538Z
#    sampling_rate: 40.0
#            delta: 0.025
#             npts: 26400
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'M', 'number_of_records': 9, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 4096, 'filesize': 516096}) 6 6

# %% [markdown]
# ### Estación 1: NNA (Perú)
# Distancia: 119.22$^\circ$\
# Azimuth: 70.24$^\circ$\
# Elevación: 575m

# %%
# Canal 1
st_NNA[0].plot()

# %%
# Canal 2
st_NNA[1].plot()

# %%
# Canal 3
st_NNA[2].plot()

# %%
# Canal 4
st_NNA[3].plot()

# %%
# Canal 5
st_NNA[4].plot()

# %%
# Canal 6
st_NNA[5].plot()

# %% [markdown]
# ### Estación 2: RPN (Chile)
# Distancia: 111.4$^\circ$\
# Azimuth: 107.03 $^\circ$\
# Elevación: 110m

# %%
# Canal 1
st_RPN[0].plot()

# %%
# Canal 2
st_RPN[1].plot()

# %%
# Canal 3
st_RPN[2].plot()

# %%
# Canal 4
st_RPN[3].plot()

# %%
# Canal 5
st_RPN[4].plot()
